# %% [markdown]
# <a href="https://colab.research.google.com/github/Adrianapachecor/Predictions_/blob/main/Visualizacion_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Muestra la cabecera de la trama de datos
# importar una librería

from google.colab import drive
drive.mount("/drive",force_remount=True)
# Out:
# Mounted at /drive

# %%
#Import pandas , csv 
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
filename = '/content/Global Temperature Anomalies.csv'
df = pd.read_csv(filename)
df
# Out:
#     Hemisphere  Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  \
# 0       Global  1880 -0.17 -0.23 -0.08 -0.15 -0.08 -0.20 -0.17 -0.09 -0.13
# 1       Global  1881 -0.18 -0.13  0.04  0.06  0.08 -0.17  0.02 -0.02 -0.14
# 2       Global  1882  0.18  0.15  0.06 -0.15 -0.13 -0.21 -0.15 -0.06 -0.13
# 3       Global  1883 -0.28 -0.36 -0.11 -0.17 -0.16 -0.07 -0.05 -0.12 -0.20
# 4       Global  1884 -0.12 -0.07 -0.36 -0.39 -0.33 -0.34 -0.32 -0.27 -0.26
# ..         ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 418   Southern  2016  0.80  0.79  0.79  0.74  0.81  0.51  0.67  0.92  0.60
# 419   Southern  2017  0.65  0.76  0.80  0.69  0.90  0.53  0.67  0.73  0.55
# 420   Southern  2018  0.48  0.45  0.61  0.80  0.63  0.69  0.75  0.65  0.64
# 421   Southern  2019  0.66  0.78  0.80  0.77  0.73  0.65  0.86  0.79  0.64
# 422   Southern  2020  0.74  0.78  0.68  0.86  0.76  0.71  0.69  0.62  0.78
#
#       Oct   Nov   Dec   J-D   D-N   DJF   MAM   JJA   SON
# ...

# %%
df1=df.loc[df['Year']=='Global']
df2=df.loc[df['Year']=='Southern']
df
# Out:
#     Hemisphere  Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  \
# 0       Global  1880 -0.17 -0.23 -0.08 -0.15 -0.08 -0.20 -0.17 -0.09 -0.13
# 1       Global  1881 -0.18 -0.13  0.04  0.06  0.08 -0.17  0.02 -0.02 -0.14
# 2       Global  1882  0.18  0.15  0.06 -0.15 -0.13 -0.21 -0.15 -0.06 -0.13
# 3       Global  1883 -0.28 -0.36 -0.11 -0.17 -0.16 -0.07 -0.05 -0.12 -0.20
# 4       Global  1884 -0.12 -0.07 -0.36 -0.39 -0.33 -0.34 -0.32 -0.27 -0.26
# ..         ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 418   Southern  2016  0.80  0.79  0.79  0.74  0.81  0.51  0.67  0.92  0.60
# 419   Southern  2017  0.65  0.76  0.80  0.69  0.90  0.53  0.67  0.73  0.55
# 420   Southern  2018  0.48  0.45  0.61  0.80  0.63  0.69  0.75  0.65  0.64
# 421   Southern  2019  0.66  0.78  0.80  0.77  0.73  0.65  0.86  0.79  0.64
# 422   Southern  2020  0.74  0.78  0.68  0.86  0.76  0.71  0.69  0.62  0.78
#
#       Oct   Nov   Dec   J-D   D-N   DJF   MAM   JJA   SON
# ...

# %%
data = {'Hemisphere': ['Global','Global','Global','Global','Global','Southern','Southern','Southern','Southern','Southern'],
        'Year': [1880, 1881, 1882, 1883,1884,2016,2017,2018,2019,2020],
        'Jan': [-0.17,-0.18,0.18,0.28,0.12,0.80,0.65,0.48,0.66,0.74]}
df = pd.DataFrame(data)
mean_df = df['Jan'].mean()
print(mean_df)
# Out:
# 0.35600000000000004

# %%
df.groupby(['Hemisphere'])[['Year','Jan']].sum()
# Out:
#              Year   Jan
# Hemisphere
# Global       9410  0.23
# Southern    10090  3.33

# %%
muestra = df[:10].copy()
muestra
# Out:
#   Hemisphere  Year   Jan
# 0     Global  1880 -0.17
# 1     Global  1881 -0.18
# 2     Global  1882  0.18
# 3     Global  1883  0.28
# 4     Global  1884  0.12
# 5   Southern  2016  0.80
# 6   Southern  2017  0.65
# 7   Southern  2018  0.48
# 8   Southern  2019  0.66
# 9   Southern  2020  0.74

# %%
plt.figure()                                
x_values1 = df.Year.unique()
y_values1 = df.Year.value_counts().tolist()
ax = plt.subplot(1, 3, 1)                  
plt.bar(x_values1, y_values1)               
plt.title('Temperatura')              
ax.set_xticks(x_values1)                    
ax.set_xticklabels(x_values1, rotation=60)  
ax.set_xlabel('Hemisphere')            
ax.set_ylabel('Jan')
# Out:
# Text(0, 0.5, 'Jan')
